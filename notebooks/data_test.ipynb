# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../portfolio-streamlit-benragot/data/data_prod.0.3.csv')
df['date_of_production'] = pd.to_datetime(df['date_of_production'])
df['year'] = pd.DatetimeIndex(df['date_of_production']).year
df['month'] = pd.DatetimeIndex(df['date_of_production']).month
df
# Out:
#     triggered  eth_earnings  eth_price_day_of_prod date_of_production  \
# 0          \t      0.026750                2011.96         2021-06-11
# 1          \t      0.114568                1883.04         2021-06-30
# 2          \t      0.028642                1883.04         2021-07-06
# 3          \t      0.006640                2024.10         2021-07-07
# 4          \t      0.006330                1897.31         2021-07-08
# ..        ...           ...                    ...                ...
# 255         n      0.005300                2672.00         2022-03-23
# 256         o      0.000000                2803.00         2022-03-24
# 257         n      0.005000                2845.00         2022-03-25
# 258         n      0.005200                2898.00         2022-03-26
# 259         n      0.005300                3045.00         2022-03-27
#
#      elec_conso_kwh  price_kwh  ROI_target  investmentss_day_of_prod  year  \
# ...

# %%
sns.lineplot(x = df['date_of_production'],
             y = df['eth_price_day_of_prod'])
# Out:
# <AxesSubplot:xlabel='date_of_production', ylabel='eth_price_day_of_prod'>
